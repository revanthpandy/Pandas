# %%
import pandas as pd

# %%
df = pd.read_csv("messy_dataset .csv")

# %%
len(df)
# Out:
# 372

# %%
df.head()
# Out:
#      Order ID Customer Id  OrderDate  Ship Date State              City  \
# 0  ORD2263134     C934974   5/2/2025   5/8/2025    CA        sacramento
# 1  ORD3302915     C682223  1/19/2026  1/25/2026    CO  colorado springs
# 2  ORD3194095     C484668  24-Nov-25   3-Dec-25    AZ           PHOENIX
# 3  ORD7604726     C239994  12-Jul-25  16-Jul-25    NM        rio rancho
# 4  ORD2703068     C959551  2/24/2026  2/28/2026    tx           houston
#
#   Sales Channel     Category Sub Category ProductID  Quantity Unit Price  \
# 0         Phone     Clothing          hat    P32146       1.0    $841.84
# 1         Phone       Health      Protein    P49880       1.0     364.29
# 2      IN-STORE  electronics     keyboard    P32860       2.0    $845.28
# 3      in-store      GROCERY       COFFEE    P58748       4.0      582.5
# 4        online       HEALTH      Protein    P89219       1.0      419.3
#
#    Discount % TaxRate ShippingCost Order Total              Notes
# ...

# %%
df.head(20)
# Out:
#       Order ID Customer Id   OrderDate   Ship Date State              City  \
# 0   ORD2263134     C934974    5/2/2025    5/8/2025    CA        sacramento
# 1   ORD3302915     C682223   1/19/2026   1/25/2026    CO  colorado springs
# 2   ORD3194095     C484668   24-Nov-25    3-Dec-25    AZ           PHOENIX
# 3   ORD7604726     C239994   12-Jul-25   16-Jul-25    NM        rio rancho
# 4   ORD2703068     C959551   2/24/2026   2/28/2026    tx           houston
# 5   ORD9202702     C875686   8/26/2025   8/26/2025    nm        rio rancho
# 6   ORD8021803     C587594   3/21/2025   3/31/2025    OK             tulsa
# 7   ORD6121649     C842306    5-Aug-25   8/12/2025    UT    salt lake city
# 8   ORD2550336     C889242   6/17/2025   6/18/2025    NM        Rio Rancho
# 9   ORD9429344     C013819  11/11/2025  11/16/2025    NM        Las Cruces
# 10  ORD5818139     C137700   2/12/2025   2/13/2025    CA       Los Angeles
# ...
